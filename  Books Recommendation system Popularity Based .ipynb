# %% [markdown]
# ###### Books Recommendation system Project

# %%
#importing neccesary packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Reading the csv files
books = pd.read_csv ('Booksss.csv' ,  error_bad_lines = False , encoding = 'latin-1')
ratings = pd.read_csv('Book-Ratings.csv' , encoding = 'latin-1' , error_bad_lines = False , sep = ";")
users = pd.read_csv ('Usersss.csv' , error_bad_lines = False , encoding = 'latin-1')
# Out:
# C:\Users\Vicky\AppData\Local\Temp\ipykernel_8056\1538940116.py:2: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   books = pd.read_csv ('Booksss.csv' ,  error_bad_lines = False , encoding = 'latin-1')
# C:\Users\Vicky\AppData\Local\Temp\ipykernel_8056\1538940116.py:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv ('Booksss.csv' ,  error_bad_lines = False , encoding = 'latin-1')
# C:\Users\Vicky\AppData\Local\Temp\ipykernel_8056\1538940116.py:3: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   ratings = pd.read_csv('Book-Ratings.csv' , encoding = 'latin-1' , error_bad_lines = False , sep = ";")
# ...

# %%
print(books.shape)
print(users.shape)
print(ratings.shape)
# Out:
# (271360, 8)
# (278858, 3)
# (1149780, 3)

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            1
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
users.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
books.duplicated().sum()
# Out:
# 0

# %%
ratings.duplicated().sum()
# Out:
# 0

# %%
users.duplicated().sum()
# Out:
# 0

# %%
plt.figure(figsize = (20,7))
sns.histplot(ratings['Book-Rating'])
plt.show()

# %%
plt.figure(figsize = (20,7))
sns.histplot(users['Age'] , bins = 30)
plt.show()

# %%
sns.boxplot(users['Age'])
# Out:
# C:\Users\Vicky\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# ## Popularity Based Recommender Sysytem

# %% [markdown]
# #### Merging rating csv and books csv on 'ISBM' feature(column)

# %%
#This recommender will work on the top rating books

# %%
books_ratings = ratings.merge(books, on = 'ISBN')

# %%
books_ratings
# Out:
#          User-ID        ISBN  Book-Rating  \
# 0         276725  034545104X            0
# 1           2313  034545104X            5
# 2           6543  034545104X            0
# 3           8680  034545104X            5
# 4          10314  034545104X            9
# ...          ...         ...          ...
# 1031131   276688  0517145553            0
# 1031132   276688  1575660792            7
# 1031133   276690  0590907301            0
# 1031134   276704  0679752714            0
# 1031135   276704  0806917695            5
#
#                                                 Book-Title      Book-Author  \
# 0                                     Flesh Tones: A Novel       M. J. Rose
# 1                                     Flesh Tones: A Novel       M. J. Rose
# 2                                     Flesh Tones: A Novel       M. J. Rose
# 3                                     Flesh Tones: A Novel       M. J. Rose
# ...

# %%
#Now we will see the number of rating on each book title

num_rating_df=books_ratings.groupby('Book-Title').count()['Book-Rating'].reset_index()
num_rating_df.rename(columns = {'Book-Rating' : 'num-Rating'},inplace = True)
num_rating_df
# Out:
#                                                Book-Title  num-Rating
# 0        A Light in the Storm: The Civil War Diary of ...           4
# 1                                   Always Have Popsicles           1
# 2                    Apple Magic (The Collector's series)           1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...           1
# 4        Beyond IBM: Leadership Marketing and Finance ...           1
# ...                                                   ...         ...
# 241066                                    Ã?Ã?lpiraten.           2
# 241067                   Ã?Ã?rger mit Produkt X. Roman.           4
# 241068                              Ã?Ã?sterlich leben.           1
# 241069                            Ã?Ã?stlich der Berge.           3
# 241070                                Ã?Ã?thique en toc           2
#
# [241071 rows x 2 columns]

# %%
#Now we will see the average rating on each book title

avg_rating_df=books_ratings.groupby('Book-Title').mean()['Book-Rating'].reset_index()
avg_rating_df.rename(columns = {'Book-Rating' : 'avg-Rating'},inplace = True)
avg_rating_df
# Out:
#                                                Book-Title  avg-Rating
# 0        A Light in the Storm: The Civil War Diary of ...    2.250000
# 1                                   Always Have Popsicles    0.000000
# 2                    Apple Magic (The Collector's series)    0.000000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...    8.000000
# 4        Beyond IBM: Leadership Marketing and Finance ...    0.000000
# ...                                                   ...         ...
# 241066                                    Ã?Ã?lpiraten.    0.000000
# 241067                   Ã?Ã?rger mit Produkt X. Roman.    5.250000
# 241068                              Ã?Ã?sterlich leben.    7.000000
# 241069                            Ã?Ã?stlich der Berge.    2.666667
# 241070                                Ã?Ã?thique en toc    4.000000
#
# [241071 rows x 2 columns]

# %%
#Now we will merge num_rating_df and avg_rating_df
popularity_df = num_rating_df.merge(avg_rating_df , on = 'Book-Title')
popularity_df
# Out:
#                                                Book-Title  num-Rating  \
# 0        A Light in the Storm: The Civil War Diary of ...           4
# 1                                   Always Have Popsicles           1
# 2                    Apple Magic (The Collector's series)           1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...           1
# 4        Beyond IBM: Leadership Marketing and Finance ...           1
# ...                                                   ...         ...
# 241066                                    Ã?Ã?lpiraten.           2
# 241067                   Ã?Ã?rger mit Produkt X. Roman.           4
# 241068                              Ã?Ã?sterlich leben.           1
# 241069                            Ã?Ã?stlich der Berge.           3
# 241070                                Ã?Ã?thique en toc           2
#
#         avg-Rating
# 0         2.250000
# 1         0.000000
# 2         0.000000
# 3         8.000000
# 4         0.000000
# ...

# %%
#Now we will consider books having num_rating more than 200
popular_df = popularity_df[popularity_df['num-Rating']>=200].sort_values('avg-Rating',ascending = False).head(50)
popular_df
# Out:
#                                                Book-Title  num-Rating  \
# 80434   Harry Potter and the Prisoner of Azkaban (Book 3)         428
# 80422        Harry Potter and the Goblet of Fire (Book 4)         387
# 80441      Harry Potter and the Sorcerer's Stone (Book 1)         278
# 80426   Harry Potter and the Order of the Phoenix (Boo...         347
# 60582       Ender's Game (Ender Wiggins Saga (Paperback))         249
# 80414    Harry Potter and the Chamber of Secrets (Book 2)         556
# 191612  The Hobbit : The Enchanting Prelude to The Lor...         281
# 187377  The Fellowship of the Ring (The Lord of the Ri...         368
# 80445   Harry Potter and the Sorcerer's Stone (Harry P...         575
# 211384     The Two Towers (The Lord of the Rings, Part 2)         260
# 219741                              To Kill a Mockingbird         510
# 183573                                  The Da Vinci Code         898
# ...

# %%
#merging popular_df on books dataset and droping duplicates
popular_books = popular_df.merge(books , on = 'Book-Title').drop_duplicates('Book-Title')
popular_books
# Out:
#                                             Book-Title  num-Rating  \
# 0    Harry Potter and the Prisoner of Azkaban (Book 3)         428
# 3         Harry Potter and the Goblet of Fire (Book 4)         387
# 5       Harry Potter and the Sorcerer's Stone (Book 1)         278
# 9    Harry Potter and the Order of the Phoenix (Boo...         347
# 13       Ender's Game (Ender Wiggins Saga (Paperback))         249
# 17    Harry Potter and the Chamber of Secrets (Book 2)         556
# 20   The Hobbit : The Enchanting Prelude to The Lor...         281
# 21   The Fellowship of the Ring (The Lord of the Ri...         368
# 30   Harry Potter and the Sorcerer's Stone (Harry P...         575
# 32      The Two Towers (The Lord of the Rings, Part 2)         260
# 43                               To Kill a Mockingbird         510
# 51                                   The Da Vinci Code         898
# 57                  The Five People You Meet in Heaven         430
# ...

# %%
popular_books.columns
# Out:
# Index(['Book-Title', 'num-Rating', 'avg-Rating', 'ISBN', 'Book-Author',
#        'Year-Of-Publication', 'Publisher', 'Image-URL-S', 'Image-URL-M',
#        'Image-URL-L'],
#       dtype='object')

# %%
popular_books = popular_books[['Book-Title', 'Book-Author', 'Year-Of-Publication','Publisher','num-Rating', 'avg-Rating' , 'Image-URL-M']]
popular_books
# Out:
#                                             Book-Title          Book-Author  \
# 0    Harry Potter and the Prisoner of Azkaban (Book 3)        J. K. Rowling
# 3         Harry Potter and the Goblet of Fire (Book 4)        J. K. Rowling
# 5       Harry Potter and the Sorcerer's Stone (Book 1)        J. K. Rowling
# 9    Harry Potter and the Order of the Phoenix (Boo...        J. K. Rowling
# 13       Ender's Game (Ender Wiggins Saga (Paperback))     Orson Scott Card
# 17    Harry Potter and the Chamber of Secrets (Book 2)        J. K. Rowling
# 20   The Hobbit : The Enchanting Prelude to The Lor...       J.R.R. TOLKIEN
# 21   The Fellowship of the Ring (The Lord of the Ri...       J.R.R. TOLKIEN
# 30   Harry Potter and the Sorcerer's Stone (Harry P...        J. K. Rowling
# 32      The Two Towers (The Lord of the Rings, Part 2)       J.R.R. TOLKIEN
# 43                               To Kill a Mockingbird           Harper Lee
# ...
